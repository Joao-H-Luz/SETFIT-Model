# %% [markdown]
# <a href="https://colab.research.google.com/github/Joao-H-Luz/SETFIT-Model/blob/main/SETFIT_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## BIBLIOTECAS

# %%
# !pip install --upgrade pip setuptools
# !pip uninstall transformers -y
# !pip uninstall tokenizers -y
# !pip install tokenizers==0.15.2
# !pip install transformers==4.43.0
# !pip install setfit

# %%
from setfit import SetFitModel, SetFitTrainer
from datasets import load_dataset
from datasets import Dataset
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
model = SetFitModel.from_pretrained("sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")

# %% [markdown]
# ### Agents
#   - agent_plantio
#   - agent_doenca
#   - agent_clima
#   - agent_recepcao

# %% [markdown]
# ## -> Data Set

# %%
dataset_agronomia = [
    # agent_plantio (25 frases)
    {"text": "Qual a melhor hora pra jogar o milho na terra?", "label": "agent_plantio"},
    {"text": "Ô patrão, me tira uma dúvida aqui: eu tô querendo plantar milho safrinha agora, mas a terra ainda tá meio úmida da última chuva e eu não sei se espero secar mais um pouco ou se já entro com a plantadeira logo pra não perder o tempo certo da semente, o que tu acha que rende mais?", "label": "agent_plantio"},
    {"text": "Quantas semente de soja vai por metro? Me dá um norte.", "label": "agent_plantio"},
    {"text": "Eu vi o vizinho plantando soja com um espaçamento bem apertado, mas aqui em casa a gente sempre usou o padrão de 45 centímetros. Tu acha que se eu fechar mais um pouco a linha e colocar umas 12 sementes por metro eu vou colher mais ou vai acabar sufocando a planta e dando prejuízo na hora de passar a colheitadeira?", "label": "agent_plantio"},
    {"text": "Como faz pra plantar trigo sem errar a mão?", "label": "agent_plantio"},
    {"text": "Quero saber qual a profundidade certa pra enterrar o feijão, porque da última vez eu acho que afundei demais e demorou uma eternidade pra nascer, aí o mato veio com tudo e tomou conta da roça antes de eu conseguir fazer qualquer coisa.", "label": "agent_plantio"},
    {"text": "Dá pra plantar direto em cima da palha de aveia?", "label": "agent_plantio"},
    {"text": "Como abre o rego pra plantar a cana?", "label": "agent_plantio"},
    {"text": "Tô com umas semente de girassol aqui e queria saber se precisa de adubo muito forte no sulco ou se ela aguenta o tranco só com o resto que ficou da última safra de milho, porque o preço do NPK tá um absurdo e eu tô tentando economizar onde dá.", "label": "agent_plantio"},
    {"text": "Como ajeito o barro pra plantar arroz no banhado?", "label": "agent_plantio"},
    {"text": "Plantar soja cruzado vale a pena ou é conversa?", "label": "agent_plantio"},
    {"text": "Quero plantar uns pé de eucalipto, como começa?", "label": "agent_plantio"},
    {"text": "O que eu planto no inverno pra cobrir o chão?", "label": "agent_plantio"},
    {"text": "A terra tem que tá quente pra germinar o milho?", "label": "agent_plantio"},
    {"text": "Tô pensando em reformar meu pasto de braquiária que tá bem ralo e cheio de praga, mas não sei se compensa mais passar o veneno em tudo e começar do zero ou se eu só jogo umas semente por cima pra ver se dá uma revigorada no capim pro gado comer melhor no verão.", "label": "agent_plantio"},
    {"text": "Minha terra tá muito dura, vai atrapalhar o plantio?", "label": "agent_plantio"},
    {"text": "Tô correndo muito com a plantadeira, vai dar ruim?", "label": "agent_plantio"},
    {"text": "Esse tal de inoculante na soja funciona mesmo?", "label": "agent_plantio"},
    {"text": "Qual o tamanho do buraco pra plantar mandioca?", "label": "agent_plantio"},
    {"text": "Como cuida das semente que já vem com veneno?", "label": "agent_plantio"},
    {"text": "Qual o mês certo pra plantar algodão aqui?", "label": "agent_plantio"},
    {"text": "Como faço pra render mais o serviço no campo?", "label": "agent_plantio"},
    {"text": "Quanto de uréia eu coloco na hora de plantar?", "label": "agent_plantio"},
    {"text": "Qual o jeito certo de espalhar os pé de café?", "label": "agent_plantio"},
    {"text": "Como mexe nesse monitor de plantio que eu não entendo nada?", "label": "agent_plantio"},

    # agent_doenca (25 frases)
    {"text": "Minha soja tá com umas mancha de ferrugem, o que eu faço?", "label": "agent_doenca"},
    {"text": "Escuta, eu tava andando no meio da roça hoje cedo e notei que as folha de baixo da soja tão cheia de umas pintinha amarela que depois fica marrom, será que isso já é aquela ferrugem braba e eu tenho que entrar correndo com o fungicida antes que espalhe pro resto de tudo?", "label": "agent_doenca"},
    {"text": "O trigo tá ficando todo branco, parece mofo, o que é?", "label": "agent_doenca"},
    {"text": "A lagarta do cartucho tá acabando com o meu milharal e o veneno que eu joguei semana passada parece que não fez nem cócegas nelas, será que essas bicha tão ficando resistente ou eu que errei na dose da mistura no tanque do pulverizador?", "label": "agent_doenca"},
    {"text": "O feijão tá ficando todo manchado, o que eu jogo?", "label": "agent_doenca"},
    {"text": "Por que a folha do meu tomate tá ficando amarela?", "label": "agent_doenca"},
    {"text": "O pé de fruta tá morrendo pela raiz, tem cura?", "label": "agent_doenca"},
    {"text": "Eu reparei que tem uns pé de milho que tão ficando meio murcho do nada, aí quando eu puxo a planta ela sai fácil e a raiz tá toda comida, tem algum bicho debaixo da terra fazendo esse estrago ou pode ser algum tipo de podridão por causa do excesso de água?", "label": "agent_doenca"},
    {"text": "A planta tá doente ou é falta de comida na terra?", "label": "agent_doenca"},
    {"text": "Meu arroz tá ficando seco e morrendo, ajuda aqui.", "label": "agent_doenca"},
    {"text": "Como acaba com o mofo branco que deu na soja?", "label": "agent_doenca"},
    {"text": "O pulgão passou doença pras minhas planta?", "label": "agent_doenca"},
    {"text": "A batata tá apodrecendo tudo na roça, e agora?", "label": "agent_doenca"},
    {"text": "Apareceu umas pinta preta no meu pé de pêssego e a fruta tá caindo antes de madurar, o que eu posso passar pra não perder a colheita toda desse ano, porque eu dependo desse dinheiro pra pagar as conta do mês que vem?", "label": "agent_doenca"},
    {"text": "Tem algum remédio natural pra matar os bicho da terra?", "label": "agent_doenca"},
    {"text": "Depois que choveu apareceu um monte de fungo, o que eu faço?", "label": "agent_doenca"},
    {"text": "Dá pra salvar a planta que tá com murchadeira?", "label": "agent_doenca"},
    {"text": "Como faz aquela mistura de calda pra passar nas planta?", "label": "agent_doenca"},
    {"text": "O talo do milho tá podre por dentro, o que é isso?", "label": "agent_doenca"},
    {"text": "Apareceu uma nuvem de mosca branca, como mata?", "label": "agent_doenca"},
    {"text": "Qual o segredo pra roça não pegar doença?", "label": "agent_doenca"},
    {"text": "Muita chuva faz as folha apodrecer mais rápido?", "label": "agent_doenca"},
    {"text": "Tem que olhar debaixo da folha pra ver se tem bicho?", "label": "agent_doenca"},
    {"text": "Mudar a planta de lugar ajuda a não dar doença?", "label": "agent_doenca"},
    {"text": "O veneno não tá fazendo mais efeito nos bicho, por que?", "label": "agent_doenca"},

    # agent_clima (25 frases)
    {"text": "Vai dar geada essa noite lá pro lado de Passo Fundo?", "label": "agent_clima"},
    {"text": "Eu vi na TV que tá vindo uma frente fria muito forte pro sul e eu tô morrendo de medo de dar uma geada negra e queimar todo o meu trigo que tá na fase de embonecamento, tem como tu me confirmar se o risco é real aqui pra minha região?", "label": "agent_clima"},
    {"text": "Esse tal de El Niño vai atrapalhar a colheita?", "label": "agent_clima"},
    {"text": "Vai chover muito essa semana ou vai dar pra trabalhar?", "label": "agent_clima"},
    {"text": "Me diz uma coisa, se começar a armar temporal com granizo, tem alguma coisa que eu possa fazer pra proteger a plantação de fumo que tá quase no ponto de colher ou o jeito é só rezar mesmo pra não estragar a folha toda?", "label": "agent_clima"},
    {"text": "A seca tá braba, vai perder muita soja?", "label": "agent_clima"},
    {"text": "Dá pra passar veneno com esse mormaço que tá?", "label": "agent_clima"},
    {"text": "Onde eu vejo se vai chover no meu pedaço de terra?", "label": "agent_clima"},
    {"text": "O tempo tá muito doido, uma hora faz um sol de rachar a mamona e na outra cai um pé d'água que alaga tudo, como é que a gente faz pra planejar o plantio desse jeito sem saber se vai ter umidade ou se vai afogar a semente?", "label": "agent_clima"},
    {"text": "Vai parar de chover quando em janeiro? Tá foda.", "label": "agent_clima"},
    {"text": "Qual a melhor hora pra molhar as planta sem queimar?", "label": "agent_clima"},
    {"text": "O sol tá muito forte, a planta aguenta?", "label": "agent_clima"},
    {"text": "O tempo vai firmar pra eu entrar com a colheitadeira?", "label": "agent_clima"},
    {"text": "Tô vendo que o vento tá soprando muito forte pro lado leste, será que se eu pulverizar agora o veneno vai todo pro vizinho ou a gota é pesada o suficiente pra cair onde eu quero?", "label": "agent_clima"},
    {"text": "O calor tá cozinhando a soja no campo.", "label": "agent_clima"},
    {"text": "Esse ano vai fazer frio o suficiente pras maçã?", "label": "agent_clima"},
    {"text": "Como eu vejo se a terra tá muito seca lá no fundo?", "label": "agent_clima"},
    {"text": "Quanto que choveu por aqui no mês passado?", "label": "agent_clima"},
    {"text": "O que eu faço pra não perder tudo na seca da La Niña?", "label": "agent_clima"},
    {"text": "Disseram que vem um vento muito forte por aí, é verdade?", "label": "agent_clima"},
    {"text": "Me manda aquele mapa da chuva em tempo real.", "label": "agent_clima"},
    {"text": "Será que esse mormaço é sinal que vem temporal brabo por aí?", "label": "agent_clima"},
    {"text": "O céu tá ficando preto pro lado do Uruguai, vai chegar aqui?", "label": "agent_clima"},
    {"text": "A umidade tá muito baixa pra passar o herbicida?", "label": "agent_clima"},
    {"text": "Quando é que esse sol vai dar uma trégua pra nós?", "label": "agent_clima"},

    # agent_recepcao (25 frases)
    {"text": "Opa, tem algum doutor das planta aí pra me ajudar?", "label": "agent_recepcao"},
    {"text": "Oi, bom dia, eu queria falar com um agrônomo que entenda de solo porque eu fiz uma análise da minha terra e não tô entendendo nada desses número que o laboratório mandou, preciso de alguém que me explique o que eu tenho que comprar de adubo.", "label": "agent_recepcao"},
    {"text": "Queria que alguém desse uma olhada aqui na minha roça.", "label": "agent_recepcao"},
    {"text": "Me passa pra quem vende semente, por favor.", "label": "agent_recepcao"},
    {"text": "Bom dia, não tô conseguindo entrar no meu cadastro.", "label": "agent_recepcao"},
    {"text": "Tô precisando de uma ajuda porque meu cadastro no sistema da cooperativa tá dando erro e eu não consigo ver se o meu crédito pra safra já foi aprovado, será que tu consegue me passar pra alguém que resolve essa parte de papelada?", "label": "agent_recepcao"},
    {"text": "Que hora que a cooperativa abre pra nós?", "label": "agent_recepcao"},
    {"text": "Quanto custa pra ver se a minha terra tá boa?", "label": "agent_recepcao"},
    {"text": "Onde que eu entrego meu caminhão de grão?", "label": "agent_recepcao"},
    {"text": "Eu queria saber se vocês ainda tão recebendo soja lá no armazém da vila ou se já lotou tudo e eu vou ter que levar o caminhão lá pra cidade vizinha pra conseguir descarregar a carga de hoje.", "label": "agent_recepcao"},
    {"text": "Quero vender minhas coisa pra vocês, como faz?", "label": "agent_recepcao"},
    {"text": "Meu aplicativo da roça deu pau, quem me ajuda?", "label": "agent_recepcao"},
    {"text": "Vocês ajudam quem tem só um pedacinho de terra?", "label": "agent_recepcao"},
    {"text": "Me manda as notícia da roça no zap.", "label": "agent_recepcao"},
    {"text": "Me dá o número do chefe aí, preciso falar com ele.", "label": "agent_recepcao"},
    {"text": "Minha conta veio errada, quem resolve?", "label": "agent_recepcao"},
    {"text": "Tem algum folheto das máquina que vocês têm?", "label": "agent_recepcao"},
    {"text": "Como que vocês entregam os veneno aqui?", "label": "agent_recepcao"},
    {"text": "O que precisa pra pegar dinheiro no banco pro plantio?", "label": "agent_recepcao"},
    {"text": "Opa, eu vi que vai ter um dia de campo aí na fazenda experimental semana que vem e queria saber se precisa pagar alguma coisa pra participar ou se é só chegar lá na hora e colocar o nome na lista pra ganhar o almoço e ver as palestra.", "label": "agent_recepcao"},
    {"text": "Oi, tem alguém aí agora ou já fecharam pra janta?", "label": "agent_recepcao"},
    {"text": "Queria saber o preço da semente de milho de hoje.", "label": "agent_recepcao"},
    {"text": "Me falaram que vocês dão curso pra quem planta fumo, como faz?", "label": "agent_recepcao"},
    {"text": "Pode me mandar o boleto do adubo por aqui?", "label": "agent_recepcao"},
    {"text": "Valeu aí pela atenção, fica com Deus.", "label": "agent_recepcao"}
]

# %%
df = Dataset.from_list(dataset_agronomia)

# %% [markdown]
# ## Treinamento

# %%
trainer = SetFitTrainer(
    model=model,
    train_dataset=df,
    column_mapping={"text": "text", "label": "label"}
)

# 4. Treinar (é muito rápido)
trainer.train()

# %% [markdown]
# ## Predição e Teste

# %%
# 5. Predição
preds = model("quantas cenouras e beterrabas cabem no trator?")
print(preds)
# Out:
# agent_plant
# /usr/local/lib/python3.12/dist-packages/google/protobuf/internal/well_known_types.py:178: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   self.FromDatetime(datetime.datetime.utcnow())
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
